# %% [markdown]
# <a href="https://colab.research.google.com/github/aarohigorle2005/Data_Science_Lab/blob/main/Experiment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment 05: Data Manipulation using Open-Source Dataset (Iris Dataset)

# Step 1: Import required libraries
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# Step 2: Load the Iris dataset
iris = load_iris()

# Step 3: Create a DataFrame
data = pd.DataFrame(iris.data, columns=iris.feature_names)

# Step 4: Add species column
data['species'] = iris.target
data['species'] = data['species'].map({0:'setosa', 1:'versicolor', 2:'virginica'})


# Step 6: Display dataset information
print("\nDataset Information:")
print(data.info())

# Step 7: Display statistical summary

print("\nStatistical Summary:")

print("Count:")
print(data.count())

print("\nMean:")
print(data.mean(numeric_only=True))

print("\nMinimum:")
print(data.min(numeric_only=True))

print("\nMaximum:")
print(data.max(numeric_only=True))

# Step 8: Filtering data (Petal length greater than 4 cm)
print("\nFiltered Data (Petal length > 4 cm):")
filtered_data = data[data['petal length (cm)'] > 4]
print(filtered_data.head())

# Step 9: Group data by species and calculate mean
print("\nMean values grouped by species:")
grouped_data = data.groupby('species').mean()
print(grouped_data)

# Step 10: Aggregate statistics

print("\nSum of values:")
print(data.sum(numeric_only=True))

print("\nMean of values:")
print(data.mean(numeric_only=True))

print("\nCount of values:")
print(data.count())

print("\nMinimum values:")
print(data.min(numeric_only=True))

print("\nMaximum values:")
print(data.max(numeric_only=True))

# Step 11: Count number of flowers in each species
print("\nNumber of flowers in each species:")
print(data['species'].value_counts())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# Statistical Summary:
# Count:
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# species              150
# dtype: int64
#
# Mean:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Minimum:
# sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# ...
